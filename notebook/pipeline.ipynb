# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import mlflow

# %% [markdown]
# ## Load Raw Data with panda

# %%
raw_data = pd.read_csv("./../data/media prediction and its cost.csv")

# %%
raw_data.head()
# Out:
#      food_category food_department food_family  store_sales(in millions)  \
# 0  Breakfast Foods    Frozen Foods        Food                      7.36
# 1  Breakfast Foods    Frozen Foods        Food                      5.52
# 2  Breakfast Foods    Frozen Foods        Food                      3.68
# 3  Breakfast Foods    Frozen Foods        Food                      3.68
# 4  Breakfast Foods    Frozen Foods        Food                      4.08
#
#    store_cost(in millions)  unit_sales(in millions)         promotion_name  \
# 0                   2.7232                      4.0           Bag Stuffers
# 1                   2.5944                      3.0  Cash Register Lottery
# 2                   1.3616                      2.0    High Roller Savings
# 3                   1.1776                      2.0  Cash Register Lottery
# 4                   1.4280                      3.0       Double Down Sale
#
#   sales_country marital_status gender  ...  grocery_sqft frozen_sqft  \
# ...

# %% [markdown]
# ## Discover and Visualize the Data to Gain Insights

# %%
raw_data.describe()
# Out:
#        store_sales(in millions)  store_cost(in millions)  \
# count              60428.000000             60428.000000
# mean                   6.541031                 2.619460
# std                    3.463047                 1.453009
# min                    0.510000                 0.163200
# 25%                    3.810000                 1.500000
# 50%                    5.940000                 2.385600
# 75%                    8.670000                 3.484025
# max                   22.920000                 9.726500
#
#        unit_sales(in millions)  total_children  avg_cars_at home(approx)  \
# count             60428.000000    60428.000000              60428.000000
# mean                  3.093169        2.533875                  2.200271
# std                   0.827677        1.490165                  1.109644
# min                   1.000000        0.000000                  0.000000
# 25%                   3.000000        1.000000                  1.000000
# ...

# %%
raw_data.dtypes
# Out:
# food_category                  object
# food_department                object
# food_family                    object
# store_sales(in millions)      float64
# store_cost(in millions)       float64
# unit_sales(in millions)       float64
# promotion_name                 object
# sales_country                  object
# marital_status                 object
# gender                         object
# total_children                float64
# education                      object
# member_card                    object
# occupation                     object
# houseowner                     object
# avg_cars_at home(approx)      float64
# avg. yearly_income             object
# num_children_at_home          float64
# avg_cars_at home(approx).1    float64
# brand_name                     object
# SRP                           float64
# gross_weight                  float64
# net_weight                    float64
# recyclable_package            float64
# low_fat                       float64
# ...

# %%
# Get all categorical columns
from sklearn.compose import make_column_selector

cat_cols = make_column_selector(dtype_include=object)(raw_data)

# %% [markdown]
# #### Visualise categorical features

# %%
cat_cols
# Out:
# ['food_category',
#  'food_department',
#  'food_family',
#  'promotion_name',
#  'sales_country',
#  'marital_status',
#  'gender',
#  'education',
#  'member_card',
#  'occupation',
#  'houseowner',
#  'avg. yearly_income',
#  'brand_name',
#  'store_type',
#  'store_city',
#  'store_state',
#  'media_type']

# %%
plt.figure(figsize=(20, 7))
plt.title("Distribution of food category")
plt.xticks(rotation=-70)
sns.histplot(data=raw_data, x='food_category')
# Out:
# <AxesSubplot:title={'center':'Distribution of food category'}, xlabel='food_category', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of Food department")
plt.xticks(rotation=-45)
sns.histplot(data=raw_data, x='food_department')
# Out:
# <AxesSubplot:title={'center':'Distribution of Food department'}, xlabel='food_department', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of Food family")
sns.histplot(data=raw_data, x='food_family')
# Out:
# <AxesSubplot:title={'center':'Distribution of Food family'}, xlabel='food_family', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of Food family")
sns.histplot(data=raw_data, x='food_family')
# Out:
# <AxesSubplot:title={'center':'Distribution of Food family'}, xlabel='food_family', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of promotion name")
plt.xticks(rotation=-80)
sns.histplot(data=raw_data, x='promotion_name')
# Out:
# <AxesSubplot:title={'center':'Distribution of promotion name'}, xlabel='promotion_name', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of sales country")
sns.histplot(data=raw_data, x='sales_country')
# Out:
# <AxesSubplot:title={'center':'Distribution of sales country'}, xlabel='sales_country', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of marital status")
sns.histplot(data=raw_data, x='marital_status')
# Out:
# <AxesSubplot:title={'center':'Distribution of marital status'}, xlabel='marital_status', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of gender")
sns.histplot(data=raw_data, x='gender')
# Out:
# <AxesSubplot:title={'center':'Distribution of gender'}, xlabel='gender', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of education")
plt.xticks(rotation=-45)
sns.histplot(data=raw_data, x='education')
# Out:
# <AxesSubplot:title={'center':'Distribution of education'}, xlabel='education', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of member card")
sns.histplot(data=raw_data, x='member_card')
# Out:
# <AxesSubplot:title={'center':'Distribution of member card'}, xlabel='member_card', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of occupation")
sns.histplot(data=raw_data, x='occupation')
# Out:
# <AxesSubplot:title={'center':'Distribution of occupation'}, xlabel='occupation', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of houseowner")
sns.histplot(data=raw_data, x='houseowner')
# Out:
# <AxesSubplot:title={'center':'Distribution of houseowner'}, xlabel='houseowner', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of avg yearly income")
plt.xticks(rotation=-45)
sns.histplot(data=raw_data, x='avg. yearly_income')
# Out:
# <AxesSubplot:title={'center':'Distribution of avg yearly income'}, xlabel='avg. yearly_income', ylabel='Count'>

# %%
plt.figure(figsize=(17, 5))
plt.title("Distribution of brand name")
plt.xticks(rotation=90)
sns.histplot(data=raw_data, x='brand_name')
# Out:
# <AxesSubplot:title={'center':'Distribution of brand name'}, xlabel='brand_name', ylabel='Count'>

# %%
plt.figure(figsize=(14, 4))
plt.title("Distribution of store type")
plt.xticks(rotation=-45)
sns.histplot(data=raw_data, x='store_type')
# Out:
# <AxesSubplot:title={'center':'Distribution of store type'}, xlabel='store_type', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of store city")
plt.xticks(rotation=-45)
sns.histplot(data=raw_data, x='store_city')
# Out:
# <AxesSubplot:title={'center':'Distribution of store city'}, xlabel='store_city', ylabel='Count'>

# %%
plt.figure(figsize=(14, 5))
plt.title("Distribution of media type")
plt.xticks(rotation=-45)
sns.histplot(data=raw_data, x='media_type')
# Out:
# <AxesSubplot:title={'center':'Distribution of media type'}, xlabel='media_type', ylabel='Count'>

# %% [markdown]
# ### Ploting correlation matrix for numerical data

# %%
# Get all categorical columns
from sklearn.compose import make_column_selector

numeric_cols = make_column_selector(dtype_include=np.float64)(raw_data)

# %%
numeric_cols
# Out:
# ['store_sales(in millions)',
#  'store_cost(in millions)',
#  'unit_sales(in millions)',
#  'total_children',
#  'avg_cars_at home(approx)',
#  'num_children_at_home',
#  'avg_cars_at home(approx).1',
#  'SRP',
#  'gross_weight',
#  'net_weight',
#  'recyclable_package',
#  'low_fat',
#  'units_per_case',
#  'store_sqft',
#  'grocery_sqft',
#  'frozen_sqft',
#  'meat_sqft',
#  'coffee_bar',
#  'video_store',
#  'salad_bar',
#  'prepared_food',
#  'florist',
#  'cost']

# %%
plt.figure(figsize=(15,5))
sns.heatmap(raw_data[numeric_cols].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Prepare the Data for Machine Learning Algorithms

# %%
# checking if there are missing values numeric features

raw_data[numeric_cols].isna().sum()
# Out:
# store_sales(in millions)      0
# store_cost(in millions)       0
# unit_sales(in millions)       0
# total_children                0
# avg_cars_at home(approx)      0
# num_children_at_home          0
# avg_cars_at home(approx).1    0
# SRP                           0
# gross_weight                  0
# net_weight                    0
# recyclable_package            0
# low_fat                       0
# units_per_case                0
# store_sqft                    0
# grocery_sqft                  0
# frozen_sqft                   0
# meat_sqft                     0
# coffee_bar                    0
# video_store                   0
# salad_bar                     0
# prepared_food                 0
# florist                       0
# cost                          0
# dtype: int64

# %%
# checking if there are missing values for categorical features
raw_data[cat_cols].isna().sum()
# Out:
# food_category         0
# food_department       0
# food_family           0
# promotion_name        0
# sales_country         0
# marital_status        0
# gender                0
# education             0
# member_card           0
# occupation            0
# houseowner            0
# avg. yearly_income    0
# brand_name            0
# store_type            0
# store_city            0
# store_state           0
# media_type            0
# dtype: int64

# %%
# Getting label
#label_name = 'cost'
#label = raw_data[label_name]
#raw_data = raw_data.drop([label_name], axis=1)

from zenml.steps import step, Output

@step(experiment_tracker="mlflow_tracker")
def data_loader()-> Output(raw_data= pd.DataFrame):
    return  pd.read_csv("./../data/media prediction and its cost.csv")

@step(experiment_tracker="mlflow_tracker")
def get_label(data: pd.DataFrame) -> Output(raw_data= pd.DataFrame, label= pd.Series):
    label = data['cost']
    return raw_data.drop(['cost'], axis=1), label

# %% [markdown]
# #### Transform data

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import make_column_transformer

scaler = StandardScaler()
encoder = OneHotEncoder()

transformer = make_column_transformer((scaler, make_column_selector(dtype_include=np.float64)),(encoder, make_column_selector(dtype_include=object)))

@step(experiment_tracker="mlflow_tracker")
def transform_data(data: pd.DataFrame) -> Output(transformed_data= np.ndarray):
    scaler = StandardScaler()
    encoder = OneHotEncoder()

    transformer = make_column_transformer((scaler, make_column_selector(dtype_include=np.float64)),
    (encoder, make_column_selector(dtype_include=object)))
    return transformer.fit_transform(raw_data).toarray()

# %%
#transformed_data = transformer.fit_transform(raw_data)

# %% [markdown]
# #### Split data

# %%
seed = 1998

from sklearn.model_selection import train_test_split

#X_train, X_test, y_train, y_test = train_test_split(transformed_data, label, test_size=0.30, random_state=seed)

@step(experiment_tracker="mlflow_tracker")
def split_data(transformed_data: np.ndarray, label: pd.Series) -> Output(X_train= np.ndarray, X_test=np.ndarray, y_train=pd.Series, y_test=pd.Series):
    X_train, X_test, y_train, y_test = train_test_split(transformed_data, label, test_size=0.30, random_state=seed)
    return X_train, X_test, y_train, y_test

# %% [markdown]
# ## Select and Train a Model

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.base import RegressorMixin

"""model = GradientBoostingRegressor()

model.fit(X_train, y_train)"""

@step(enable_cache=False, experiment_tracker="mlflow_tracker")
def train_model(X_train: np.ndarray, y_train: pd.Series) -> Output(model= RegressorMixin):
    mlflow.sklearn.autolog()
    model = GradientBoostingRegressor()
    model.fit(X_train, y_train)
    
    return model

# %% [markdown]
# #### Evaluating the model

# %%
from sklearn.metrics import mean_squared_error
import pickle

@step(experiment_tracker="mlflow_tracker")
def evaluate(model: RegressorMixin, X_test: np.ndarray, y_test: pd.Series) -> Output(metric= float):
    """ Calculate the mean squared error """
    
    y_pred = model.predict(X_test)
    metric = mean_squared_error(y_test, y_pred)
    mlflow.log_metric("metric", metric)
    return metric

@step(experiment_tracker="mlflow_tracker")
def predict(model: RegressorMixin, X: np.ndarray) -> Output(predictions= np.ndarray):
    return model.predict(X)

@step(experiment_tracker="mlflow_tracker")
def save_model(model: RegressorMixin) -> Output(filename= str):
    filename = './../artifact/model/finalized_model.sav'
    pickle.dump(model, open(filename, 'wb'))
    return filename

@step(experiment_tracker="mlflow_tracker")
def load_model() -> Output(model= RegressorMixin):
    loaded_model = pickle.load(open('finalized_model.sav', 'rb'))
    return loaded_model

# %% [markdown]
# ## Fine-Tune Your Model

# %%
from zenml.pipelines import pipeline

@pipeline(enable_cache=False)
def training_pipeline(data_loader=data_loader(),
get_label=get_label(), transform_data=transform_data(), split_data=split_data(),
train_model=train_model(), evaluate=evaluate(), save_model=save_model()):
    raw_data = data_loader()
    raw_data, label = get_label(raw_data)
    transformed_data = transform_data(raw_data)
    X_train, X_test, y_train, y_test = split_data(transformed_data, label)
    model = train_model(X_train, y_train)
    metric = evaluate(model, X_test, y_test)
    print(metric)
    save_model(model)

# %%
training_pipeline_instance = training_pipeline(data_loader(),
get_label(), transform_data(), split_data(), train_model(), evaluate(), save_model())
training_pipeline_instance.run()
# Out:
# Reloading configuration file /home/kenmogne/work/MonthOfZenmlComp/.zen/config.yaml
# _OutputArtifact(channel=OutputChannel(artifact_type=DataArtifact, producer_component_id=evaluate, output_key=metric, additional_properties={}, additional_custom_properties={}), materializer_source='zenml.materializers.built_in_materializer.BuiltInMaterializer@zenml_0.20.4')
# Creating run training_pipeline-19_Oct_22-00_55_51_277158 for pipeline training_pipeline (Caching disabled)
# Using stack default to run pipeline training_pipeline...
# Step data_loader has started.
# Step data_loader has finished in 1.375s.
# Step get_label has started.
# Step get_label has finished in 0.773s.
# Step transform_data has started.
# Step transform_data has finished in 4.184s.
# Step split_data has started.
# Step split_data has finished in 3.573s.
# Step train_model has started.
# ...
